# %%
import pandas as pd

# %%
input_name = "O3a_events_HLV_SEOBNRv4PHM_maxL.csv"
output_name = "O3a_events_HLV_SEOBNRv4PHM_maxL_T.csv"

df = pd.read_csv(input_name)

df_transposed = df.T

df_transposed.to_csv(output_name, index = True, header = False)
